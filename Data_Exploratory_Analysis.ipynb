# %% [markdown]
# # Importing Packages

# %%
#importing packages
import pandas as pd
import numpy as np

# for warnings 
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Acquire the data

# %%
data = pd.read_excel("INX_Employee_Data.xls")
data.head(10)
# Out:
#   EmpNumber  Age  Gender EducationBackground MaritalStatus    EmpDepartment  \
# 0  E1001000   32    Male           Marketing        Single            Sales
# 1  E1001006   47    Male           Marketing        Single            Sales
# 2  E1001007   40    Male       Life Sciences       Married            Sales
# 3  E1001009   41    Male     Human Resources      Divorced  Human Resources
# 4  E1001010   60    Male           Marketing        Single            Sales
# 5  E1001011   27    Male       Life Sciences      Divorced      Development
# 6  E1001016   50    Male           Marketing       Married            Sales
# 7  E1001019   28  Female       Life Sciences        Single      Development
# 8  E1001020   36  Female       Life Sciences       Married      Development
# 9  E1001021   38  Female       Life Sciences        Single      Development
#
#              EmpJobRole BusinessTravelFrequency  DistanceFromHome  \
# ...

# %%
#presenting features 
data.columns
# Out:
# Index(['EmpNumber', 'Age', 'Gender', 'EducationBackground', 'MaritalStatus',
#        'EmpDepartment', 'EmpJobRole', 'BusinessTravelFrequency',
#        'DistanceFromHome', 'EmpEducationLevel', 'EmpEnvironmentSatisfaction',
#        'EmpHourlyRate', 'EmpJobInvolvement', 'EmpJobLevel',
#        'EmpJobSatisfaction', 'NumCompaniesWorked', 'OverTime',
#        'EmpLastSalaryHikePercent', 'EmpRelationshipSatisfaction',
#        'TotalWorkExperienceInYears', 'TrainingTimesLastYear',
#        'EmpWorkLifeBalance', 'ExperienceYearsAtThisCompany',
#        'ExperienceYearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager', 'Attrition', 'PerformanceRating'],
#       dtype='object')

# %%
#dropping EmpNumber column
data.drop('EmpNumber', axis =1, inplace = True)

# %%
data.columns
# Out:
# Index(['Age', 'Gender', 'EducationBackground', 'MaritalStatus',
#        'EmpDepartment', 'EmpJobRole', 'BusinessTravelFrequency',
#        'DistanceFromHome', 'EmpEducationLevel', 'EmpEnvironmentSatisfaction',
#        'EmpHourlyRate', 'EmpJobInvolvement', 'EmpJobLevel',
#        'EmpJobSatisfaction', 'NumCompaniesWorked', 'OverTime',
#        'EmpLastSalaryHikePercent', 'EmpRelationshipSatisfaction',
#        'TotalWorkExperienceInYears', 'TrainingTimesLastYear',
#        'EmpWorkLifeBalance', 'ExperienceYearsAtThisCompany',
#        'ExperienceYearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager', 'Attrition', 'PerformanceRating'],
#       dtype='object')

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# # EmpDepartment

# %%
data.EmpDepartment.unique()
# Out:
# array(['Sales', 'Human Resources', 'Development', 'Data Science',
#        'Research & Development', 'Finance'], dtype=object)

# %% [markdown]
# EmpDepartment have 6 departments.

# %%
data.EmpDepartment.value_counts()
# Out:
# Sales                     373
# Development               361
# Research & Development    343
# Human Resources            54
# Finance                    49
# Data Science               20
# Name: EmpDepartment, dtype: int64

# %% [markdown]
# # PerformanceRating

# %%
data.PerformanceRating.unique()
# Out:
# array([3, 4, 2])

# %% [markdown]
# PerformanceRating is having 3 unique values.

# %%
data.PerformanceRating.value_counts()
# Out:
# 3    874
# 2    194
# 4    132
# Name: PerformanceRating, dtype: int64

# %% [markdown]
# Only 13% of employees in the company were achieved level 4 - performance rating.PerformanceRating looks like imbalanced data.To do balance the data we should use SMOTE technique.

# %% [markdown]
# # Age

# %%
data.Age.unique()
# Out:
# array([32, 47, 40, 41, 60, 27, 50, 28, 36, 38, 44, 30, 29, 42, 34, 39, 56,
#        53, 35, 52, 33, 25, 45, 23, 26, 54, 37, 24, 49, 55, 43, 51, 22, 31,
#        58, 20, 21, 48, 19, 18, 59, 46, 57])

# %%
data.Age.value_counts().sort_values()
# Out:
# 60     3
# 57     4
# 20     6
# 59     6
# 18     8
# 19     8
# 23     9
# 58    11
# 21    11
# 56    11
# 51    14
# 52    15
# 53    15
# 22    15
# 48    16
# 54    16
# 55    17
# 47    20
# 24    20
# 49    21
# 25    24
# 46    24
# 43    26
# 50    28
# 44    30
# 39    31
# 41    32
# 26    33
# 42    36
# 45    36
# 28    39
# 37    41
# 30    42
# 27    43
# 40    46
# 32    46
# 33    46
# 38    48
# 29    51
# 31    57
# 36    60
# 35    64
# 34    71
# Name: Age, dtype: int64

# %%
data.loc[(data['Age']>25) & (data['Age']<45)]
# Out:
#       Age  Gender EducationBackground MaritalStatus    EmpDepartment  \
# 0      32    Male           Marketing        Single            Sales
# 2      40    Male       Life Sciences       Married            Sales
# 3      41    Male     Human Resources      Divorced  Human Resources
# 5      27    Male       Life Sciences      Divorced      Development
# 7      28  Female       Life Sciences        Single      Development
# ...   ...     ...                 ...           ...              ...
# 1192   38  Female           Marketing        Single            Sales
# 1193   29    Male       Life Sciences      Divorced      Development
# 1195   27  Female             Medical      Divorced            Sales
# 1196   37    Male       Life Sciences        Single      Development
# 1198   34  Female             Medical        Single     Data Science
#
#             EmpJobRole BusinessTravelFrequency  DistanceFromHome  \
# 0      Sales Executive           Travel_Rarely                10
# ...

# %%
data.loc[(data['Age']>18) & (data['Age']<25)]
# Out:
#       Age  Gender EducationBackground MaritalStatus EmpDepartment  \
# 29     23    Male             Medical        Single   Development
# 46     24    Male       Life Sciences      Divorced   Development
# 82     22    Male       Life Sciences       Married   Development
# 90     24    Male       Life Sciences       Married   Development
# 106    20  Female             Medical        Single         Sales
# ...   ...     ...                 ...           ...           ...
# 1176   21    Male    Technical Degree        Single         Sales
# 1178   22    Male             Medical       Married   Development
# 1188   20    Male             Medical        Single   Development
# 1190   23    Male             Medical       Married   Development
# 1199   24  Female       Life Sciences        Single         Sales
#
#                 EmpJobRole BusinessTravelFrequency  DistanceFromHome  \
# 29               Developer           Travel_Rarely                10
# ...

# %%
data.loc[(data['Age']>45) & (data['Age']<60)]
# Out:
#       Age  Gender EducationBackground MaritalStatus    EmpDepartment  \
# 1      47    Male           Marketing        Single            Sales
# 6      50    Male           Marketing       Married            Sales
# 11     47  Female             Medical      Divorced            Sales
# 17     56    Male             Medical       Married      Development
# 21     53    Male       Life Sciences        Single      Development
# ...   ...     ...                 ...           ...              ...
# 1160   50    Male             Medical       Married  Human Resources
# 1172   48  Female       Life Sciences       Married      Development
# 1186   54    Male             Medical       Married  Human Resources
# 1194   48    Male           Marketing       Married            Sales
# 1197   50    Male             Medical       Married      Development
#
#                 EmpJobRole BusinessTravelFrequency  DistanceFromHome  \
# ...

# %% [markdown]
# The age distribution is starting from 18 to 60 where the most of the employees are lying between 25 to 45 age count.

# %% [markdown]
# # Gender

# %%
data.Gender.unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
data.Gender.value_counts()
# Out:
# Male      725
# Female    475
# Name: Gender, dtype: int64

# %% [markdown]
# The Gender variance is divided by 60% of Male employees and 40% of Female employees in the company.

# %% [markdown]
# # EmpJobRole

# %%
data.EmpJobRole.unique()
# Out:
# array(['Sales Executive', 'Manager', 'Developer', 'Sales Representative',
#        'Human Resources', 'Senior Developer', 'Data Scientist',
#        'Senior Manager R&D', 'Laboratory Technician',
#        'Manufacturing Director', 'Research Scientist',
#        'Healthcare Representative', 'Research Director', 'Manager R&D',
#        'Finance Manager', 'Technical Architect', 'Business Analyst',
#        'Technical Lead', 'Delivery Manager'], dtype=object)

# %%
data.EmpJobRole.value_counts()
# Out:
# Sales Executive              270
# Developer                    236
# Manager R&D                   94
# Research Scientist            77
# Sales Representative          69
# Laboratory Technician         64
# Senior Developer              52
# Manager                       51
# Finance Manager               49
# Human Resources               45
# Technical Lead                38
# Manufacturing Director        33
# Healthcare Representative     33
# Data Scientist                20
# Research Director             19
# Business Analyst              16
# Senior Manager R&D            15
# Delivery Manager              12
# Technical Architect            7
# Name: EmpJobRole, dtype: int64

# %% [markdown]
# # DistanceFromHome

# %%
data.DistanceFromHome.unique()
# Out:
# array([10, 14,  5, 16,  8,  1, 24,  3, 27, 19,  9,  2,  7,  6, 26, 11, 23,
#        13, 29, 12,  4, 25, 21, 18, 20, 17, 22, 28, 15])

# %%
data.DistanceFromHome.value_counts()
# Out:
# 2     184
# 1     170
# 8      69
# 3      67
# 10     66
# 9      66
# 7      65
# 5      54
# 4      51
# 6      46
# 16     25
# 11     25
# 18     24
# 24     23
# 29     23
# 23     22
# 26     22
# 28     20
# 25     19
# 20     19
# 19     18
# 14     17
# 17     17
# 22     17
# 15     17
# 12     16
# 21     15
# 13     14
# 27      9
# Name: DistanceFromHome, dtype: int64

# %% [markdown]
# The distance from home to office is distributing from 1 unit to 29 unit which can be kilometre or mile. The most of the employees are coming from the range of 1 to 10 units.

# %% [markdown]
# # EmpEnvironmentSatisfaction

# %%
data.EmpEnvironmentSatisfaction.unique()
# Out:
# array([4, 2, 1, 3])

# %%
data.EmpEnvironmentSatisfaction.value_counts()
# Out:
# 3    367
# 4    361
# 2    242
# 1    230
# Name: EmpEnvironmentSatisfaction, dtype: int64

# %% [markdown]
# The Job satisfaction level in this company is high level for the majority of employees.

# %% [markdown]
# # EmpHourlyRate

# %%
data.EmpHourlyRate.unique()
# Out:
# array([ 55,  42,  48,  73,  84,  32,  54,  67,  63,  81,  49,  99,  57,
#         96,  44,  86,  83,  61,  80,  31,  46,  79,  77,  60,  76,  41,
#         71,  66,  38,  72,  95,  82,  75,  93,  64,  36,  69,  33,  35,
#         40,  43,  51,  52,  98,  45,  37,  94,  59,  88,  50,  65,  53,
#         56,  78,  74,  91,  62,  87,  68,  34,  70, 100,  92,  39,  97,
#         47,  90,  85,  30,  58,  89])

# %%
data.EmpHourlyRate.value_counts()
# Out:
# 66    25
# 79    25
# 42    24
# 57    23
# 46    23
#       ..
# 49    12
# 47    11
# 38    10
# 89     8
# 34     6
# Name: EmpHourlyRate, Length: 71, dtype: int64

# %%
data.loc[(data['EmpHourlyRate']>60) & (data['EmpHourlyRate']<100)]
# Out:
#       Age  Gender EducationBackground MaritalStatus    EmpDepartment  \
# 3      41    Male     Human Resources      Divorced  Human Resources
# 4      60    Male           Marketing        Single            Sales
# 7      28  Female       Life Sciences        Single      Development
# 8      36  Female       Life Sciences       Married      Development
# 9      38  Female       Life Sciences        Single      Development
# ...   ...     ...                 ...           ...              ...
# 1193   29    Male       Life Sciences      Divorced      Development
# 1195   27  Female             Medical      Divorced            Sales
# 1196   37    Male       Life Sciences        Single      Development
# 1197   50    Male             Medical       Married      Development
# 1199   24  Female       Life Sciences        Single            Sales
#
#             EmpJobRole BusinessTravelFrequency  DistanceFromHome  \
# 3              Manager           Travel_Rarely                10
# ...

# %%
data.loc[(data['EmpHourlyRate']>40) & (data['EmpHourlyRate']<60)]
# Out:
#       Age  Gender EducationBackground MaritalStatus EmpDepartment  \
# 0      32    Male           Marketing        Single         Sales
# 1      47    Male           Marketing        Single         Sales
# 2      40    Male       Life Sciences       Married         Sales
# 6      50    Male           Marketing       Married         Sales
# 10     44    Male             Medical        Single   Development
# ...   ...     ...                 ...           ...           ...
# 1190   23    Male             Medical       Married   Development
# 1191   25    Male       Life Sciences       Married         Sales
# 1192   38  Female           Marketing        Single         Sales
# 1194   48    Male           Marketing       Married         Sales
# 1198   34  Female             Medical        Single  Data Science
#
#                 EmpJobRole BusinessTravelFrequency  DistanceFromHome  \
# 0          Sales Executive           Travel_Rarely                10
# ...

# %%
data.loc[(data['EmpHourlyRate']<40)]
# Out:
#       Age  Gender EducationBackground MaritalStatus EmpDepartment  \
# 5      27    Male       Life Sciences      Divorced   Development
# 24     34  Female       Life Sciences      Divorced   Development
# 25     52    Male           Marketing       Married         Sales
# 27     25  Female             Medical        Single         Sales
# 36     26    Male    Technical Degree        Single         Sales
# ...   ...     ...                 ...           ...           ...
# 1134   48  Female           Marketing       Married         Sales
# 1174   34  Female    Technical Degree      Divorced         Sales
# 1177   44    Male               Other       Married   Development
# 1183   37    Male               Other       Married   Development
# 1188   20    Male             Medical        Single   Development
#
#                 EmpJobRole BusinessTravelFrequency  DistanceFromHome  \
# 5                Developer       Travel_Frequently                10
# ...

# %% [markdown]
# The hourly rate range is 60 to 100 for majority employees work in this company.

# %% [markdown]
# # EmpJobInvolvement

# %%
data.EmpJobInvolvement.unique()
# Out:
# array([3, 2, 1, 4])

# %%
data.EmpJobInvolvement.value_counts()
# Out:
# 3    724
# 2    294
# 4    112
# 1     70
# Name: EmpJobInvolvement, dtype: int64

# %% [markdown]
# The Employee Job involvement level in this company is high level for the majority of employees.

# %% [markdown]
# # EmpJobSatisfaction

# %%
data.EmpJobSatisfaction.unique()
# Out:
# array([4, 1, 2, 3])

# %%
data.EmpJobSatisfaction.value_counts()
# Out:
# 4    378
# 3    354
# 2    237
# 1    231
# Name: EmpJobSatisfaction, dtype: int64

# %% [markdown]
# The Job satisfaction level in this company is high level for the majority of employees

# %% [markdown]
# # OverTime

# %%
data.OverTime.unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
data.OverTime.value_counts()
# Out:
# No     847
# Yes    353
# Name: OverTime, dtype: int64

# %% [markdown]
# The overall percentage of employees doing overtime is 30%

# %% [markdown]
# # EmpLastSalaryHikePercent

# %%
data.EmpLastSalaryHikePercent.unique()
# Out:
# array([12, 21, 15, 14, 13, 23, 11, 20, 19, 17, 18, 22, 16, 24, 25])

# %%
data.EmpLastSalaryHikePercent.value_counts()
# Out:
# 14    172
# 11    169
# 13    168
# 12    155
# 15     82
# 18     73
# 16     68
# 17     67
# 19     63
# 20     50
# 22     47
# 21     34
# 23     21
# 24     18
# 25     13
# Name: EmpLastSalaryHikePercent, dtype: int64

# %% [markdown]
# Most of the employees get 11% to 15% of salary hike in this company.

# %% [markdown]
# # EmpWorkLifeBalance

# %%
data.EmpWorkLifeBalance.unique()
# Out:
# array([2, 3, 4, 1])

# %%
data.EmpWorkLifeBalance.value_counts()
# Out:
# 3    727
# 2    294
# 4    115
# 1     64
# Name: EmpWorkLifeBalance, dtype: int64

# %% [markdown]
# Employee work life balance level is 11% in 4th level and 72% in 3rd level.

# %% [markdown]
# # YearsSinceLastPromotion

# %%
data.YearsSinceLastPromotion.unique()
# Out:
# array([ 0,  1, 12,  2,  3, 11,  7,  4,  5, 14,  8, 15,  6, 10, 13,  9])

# %%
data.YearsSinceLastPromotion.value_counts()
# Out:
# 0     469
# 1     297
# 2     127
# 7      62
# 4      53
# 3      45
# 5      35
# 6      24
# 11     23
# 9      16
# 8      11
# 15     11
# 12      9
# 13      8
# 14      5
# 10      5
# Name: YearsSinceLastPromotion, dtype: int64

# %% [markdown]
# Most of the Employees got their promotion from 0 to 2 years.Some of the employees got their promotions after long years.

# %% [markdown]
# # Attrition

# %%
data.Attrition.unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
data.Attrition.value_counts()
# Out:
# No     1022
# Yes     178
# Name: Attrition, dtype: int64

# %% [markdown]
# The 85% of employees are not having attrition in their work

# %% [markdown]
# # Analyzing Correlation

# %%
data.corr()
# Out:
#                                    Age  DistanceFromHome  EmpEducationLevel  \
# Age                           1.000000          0.020937           0.207313
# DistanceFromHome              0.020937          1.000000           0.045856
# EmpEducationLevel             0.207313          0.045856           1.000000
# EmpEnvironmentSatisfaction    0.013814         -0.017719          -0.037103
# EmpHourlyRate                 0.062867          0.013730           0.014095
# EmpJobInvolvement             0.027216          0.003231           0.027544
# EmpJobLevel                   0.509139          0.017270           0.100734
# EmpJobSatisfaction           -0.002436         -0.003036           0.000357
# NumCompaniesWorked            0.284408         -0.021411           0.128674
# EmpLastSalaryHikePercent     -0.006105          0.044974           0.002358
# EmpRelationshipSatisfaction   0.049749         -0.009509          -0.016690
# ...

# %% [markdown]
# From the above Correlation between features with numerical values in the dataset.The signatures show the level of correlation from 0 to 1. From this distribution we can derive the facts as follows,
#
# 1. The Total years of experience and job level are having the higher correlation when comparing to all features.
#
# 2. Experience years at this company and years with the current manager has the second higher relation between these features.
#
# 3. Experience years at this company and experience in the current role,Total work experience in years, Year since last promotion, employee work life balance makes the sense of correlation.
#
# 4. People who have more experience with the company has the more probability to get the promotion from the correlation between them.
#
# 5. The age has the important role in the total number of work experience of an employee and the Employee Job level where it is a universal truth.
#
# 6. Employee Environment Satisfaction, Employee Last Salary hike percent, employee work life balance are having correlation with Performance rating.
